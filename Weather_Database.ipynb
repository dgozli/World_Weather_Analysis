# %%
import numpy as np
import pandas as pd
from citipy import citipy
from config import weather_api_key
import requests
import time

# %%
# Creating a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# Getting the nearest city using the citipy module.
cities = []
# Identifying the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describe = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(), 
                          "Country":city_country,"Lat": city_lat,
                          "Lng": city_lng, "Max Temp": city_max_temp,
                          "Humidity": city_humidity, 
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_describe})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | san patricio
# Processing Record 6 of Set 1 | san cristobal
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | sur
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | gunjur
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | ouesso
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | passo de camaragibe
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | cherskiy
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | tananger
# Processing Record 30 of Set 1 | hovd
# Processing Record 31 of Set 1 | okhotsk
# Processing Record 32 of Set 1 | nosivka
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | northam
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | gizo
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | nhulunbuy
# Processing Record 42 of Set 1 | mogadishu
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | semirom
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | ulladulla
# Processing Record 47 of Set 1 | hualmay
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | ancud
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | san antonio
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | macau
# Processing Record 6 of Set 2 | sarkand
# Processing Record 7 of Set 2 | yazman
# Processing Record 8 of Set 2 | kidal
# Processing Record 9 of Set 2 | iberia
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | dingle
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 2 | waingapu
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | lashio
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | faya
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | hami
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | gravdal
# Processing Record 24 of Set 2 | elko
# Processing Record 25 of Set 2 | horadiz
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | sorong
# Processing Record 28 of Set 2 | moroni
# Processing Record 29 of Set 2 | te anau
# Processing Record 30 of Set 2 | kalmunai
# Processing Record 31 of Set 2 | ladybrand
# Processing Record 32 of Set 2 | makat
# Processing Record 33 of Set 2 | ketchenery
# City not found. Skipping...
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | hargeysa
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | anadyr
# Processing Record 39 of Set 2 | mehamn
# Processing Record 40 of Set 2 | kamina
# Processing Record 41 of Set 2 | horana
# Processing Record 42 of Set 2 | dawson creek
# Processing Record 43 of Set 2 | sao felix do xingu
# Processing Record 44 of Set 2 | pangoa
# Processing Record 45 of Set 2 | filingue
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | saint-louis
# Processing Record 48 of Set 2 | estelle
# Processing Record 49 of Set 2 | coahuayana
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | comodoro rivadavia
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | zyryanka
# Processing Record 5 of Set 3 | gannan
# Processing Record 6 of Set 3 | mochicahui
# Processing Record 7 of Set 3 | chik
# Processing Record 8 of Set 3 | dali
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | samarai
# Processing Record 11 of Set 3 | kastamonu
# Processing Record 12 of Set 3 | borba
# Processing Record 13 of Set 3 | saint-georges
# Processing Record 14 of Set 3 | meulaboh
# Processing Record 15 of Set 3 | huilong
# Processing Record 16 of Set 3 | vung tau
# Processing Record 17 of Set 3 | turayf
# Processing Record 18 of Set 3 | uribia
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | cap malheureux
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | beisfjord
# Processing Record 23 of Set 3 | bathsheba
# Processing Record 24 of Set 3 | salinas
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | bilibino
# Processing Record 28 of Set 3 | gamba
# Processing Record 29 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | vrangel
# Processing Record 32 of Set 3 | jandiala
# Processing Record 33 of Set 3 | nakama
# Processing Record 34 of Set 3 | salinopolis
# Processing Record 35 of Set 3 | atikokan
# Processing Record 36 of Set 3 | krasnovishersk
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | phangnga
# Processing Record 39 of Set 3 | collie
# Processing Record 40 of Set 3 | mareeba
# Processing Record 41 of Set 3 | lagoa
# Processing Record 42 of Set 3 | saldanha
# Processing Record 43 of Set 3 | yaan
# Processing Record 44 of Set 3 | whitecourt
# Processing Record 45 of Set 3 | kembe
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | progreso
# Processing Record 48 of Set 3 | truro
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | luanda
# Processing Record 2 of Set 4 | beloha
# Processing Record 3 of Set 4 | wilmington
# Processing Record 4 of Set 4 | antsohihy
# Processing Record 5 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 4 | valverde del camino
# Processing Record 8 of Set 4 | turukhansk
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | iquique
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | raduzhnyy
# Processing Record 15 of Set 4 | guerrero negro
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | itambacuri
# Processing Record 18 of Set 4 | naliya
# Processing Record 19 of Set 4 | dwarka
# Processing Record 20 of Set 4 | sakakah
# Processing Record 21 of Set 4 | provideniya
# Processing Record 22 of Set 4 | severo-kurilsk
# Processing Record 23 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | zhangye
# Processing Record 27 of Set 4 | bluff
# Processing Record 28 of Set 4 | brockville
# Processing Record 29 of Set 4 | vostok
# Processing Record 30 of Set 4 | beringovskiy
# Processing Record 31 of Set 4 | hasaki
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | kroya
# Processing Record 34 of Set 4 | tauteu
# Processing Record 35 of Set 4 | teguldet
# Processing Record 36 of Set 4 | karpathos
# Processing Record 37 of Set 4 | walvis bay
# City not found. Skipping...
# Processing Record 38 of Set 4 | new norfolk
# City not found. Skipping...
# Processing Record 39 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 4 | starodub
# City not found. Skipping...
# Processing Record 41 of Set 4 | wadi maliz
# City not found. Skipping...
# Processing Record 42 of Set 4 | aklavik
# City not found. Skipping...
# Processing Record 43 of Set 4 | nome
# City not found. Skipping...
# Processing Record 44 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 4 | saint-vallier
# City not found. Skipping...
# Processing Record 46 of Set 4 | qostanay
# City not found. Skipping...
# Processing Record 47 of Set 4 | kandrian
# Processing Record 48 of Set 4 | kirakira
# City not found. Skipping...
# Processing Record 49 of Set 4 | ribeira grande
# City not found. Skipping...
# Processing Record 50 of Set 4 | isangel
# City not found. Skipping...
# Processing Record 1 of Set 5 | djambala
# Processing Record 2 of Set 5 | ola
# Processing Record 3 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 4 of Set 5 | esso
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 5 | barranca
# Processing Record 7 of Set 5 | hithadhoo
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | broome
# Processing Record 11 of Set 5 | clarence town
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | la ronge
# Processing Record 14 of Set 5 | preobrazheniye
# Processing Record 15 of Set 5 | anchorage
# Processing Record 16 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 17 of Set 5 | guerrero
# Processing Record 18 of Set 5 | narsaq
# Processing Record 19 of Set 5 | tezu
# Processing Record 20 of Set 5 | marzuq
# Processing Record 21 of Set 5 | shimoda
# City not found. Skipping...
# Processing Record 22 of Set 5 | kieta
# City not found. Skipping...
# Processing Record 23 of Set 5 | husavik
# City not found. Skipping...
# Processing Record 24 of Set 5 | luderitz
# City not found. Skipping...
# Processing Record 25 of Set 5 | kontagora
# City not found. Skipping...
# Processing Record 26 of Set 5 | kolokani
# Processing Record 27 of Set 5 | krasnoselkup
# City not found. Skipping...
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | channel-port aux basques
# Processing Record 30 of Set 5 | grindavik
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | torbay
# City not found. Skipping...
# Processing Record 33 of Set 5 | dossor
# City not found. Skipping...
# Processing Record 34 of Set 5 | nipawin
# City not found. Skipping...
# Processing Record 35 of Set 5 | simao
# City not found. Skipping...
# Processing Record 36 of Set 5 | aktash
# City not found. Skipping...
# Processing Record 37 of Set 5 | inongo
# City not found. Skipping...
# Processing Record 38 of Set 5 | mizan teferi
# City not found. Skipping...
# Processing Record 39 of Set 5 | tessalit
# City not found. Skipping...
# Processing Record 40 of Set 5 | plainview
# Processing Record 41 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 5 | portland
# City not found. Skipping...
# Processing Record 43 of Set 5 | tasiilaq
# Processing Record 44 of Set 5 | port antonio
# City not found. Skipping...
# Processing Record 45 of Set 5 | santiago de cao
# Processing Record 46 of Set 5 | zyryanovsk
# City not found. Skipping...
# Processing Record 47 of Set 5 | cape town
# Processing Record 48 of Set 5 | constitucion
# City not found. Skipping...
# Processing Record 49 of Set 5 | rio gallegos
# City not found. Skipping...
# Processing Record 50 of Set 5 | rosetta
# Processing Record 1 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 6 | jijiang
# Processing Record 3 of Set 6 | sawakin
# Processing Record 4 of Set 6 | grand gaube
# City not found. Skipping...
# Processing Record 5 of Set 6 | bubaque
# Processing Record 6 of Set 6 | deputatskiy
# City not found. Skipping...
# Processing Record 7 of Set 6 | thinadhoo
# Processing Record 8 of Set 6 | san rafael
# Processing Record 9 of Set 6 | paris
# Processing Record 10 of Set 6 | nichlaul
# Processing Record 11 of Set 6 | zhigansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | nailsea
# Processing Record 13 of Set 6 | yenagoa
# City not found. Skipping...
# Processing Record 14 of Set 6 | biltine
# City not found. Skipping...
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | fort smith
# City not found. Skipping...
# Processing Record 18 of Set 6 | maarianhamina
# City not found. Skipping...
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | buala
# City not found. Skipping...
# Processing Record 21 of Set 6 | fukue
# City not found. Skipping...
# Processing Record 22 of Set 6 | linjiang
# City not found. Skipping...
# Processing Record 23 of Set 6 | namibe
# City not found. Skipping...
# Processing Record 24 of Set 6 | saint-augustin
# City not found. Skipping...
# Processing Record 25 of Set 6 | martinez
# City not found. Skipping...
# Processing Record 26 of Set 6 | roma
# City not found. Skipping...
# Processing Record 27 of Set 6 | clyde river
# City not found. Skipping...
# Processing Record 28 of Set 6 | nikolskoye
# City not found. Skipping...
# Processing Record 29 of Set 6 | matagami
# City not found. Skipping...
# Processing Record 30 of Set 6 | pingliang
# City not found. Skipping...
# Processing Record 31 of Set 6 | jardim
# City not found. Skipping...
# Processing Record 32 of Set 6 | asilah
# Processing Record 33 of Set 6 | ketchikan
# Processing Record 34 of Set 6 | keffi
# Processing Record 35 of Set 6 | evensk
# Processing Record 36 of Set 6 | puerto del rosario
# Processing Record 37 of Set 6 | almaznyy
# Processing Record 38 of Set 6 | birjand
# Processing Record 39 of Set 6 | fortuna
# Processing Record 40 of Set 6 | antoniny
# Processing Record 41 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 6 | bauchi
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | srednekolymsk
# Processing Record 45 of Set 6 | kassala
# Processing Record 46 of Set 6 | aitape
# Processing Record 47 of Set 6 | orsk
# Processing Record 48 of Set 6 | kargasok
# Processing Record 49 of Set 6 | bulgan
# Processing Record 50 of Set 6 | vila velha
# Processing Record 1 of Set 7 | pontes e lacerda
# Processing Record 2 of Set 7 | sobolevo
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | biak
# Processing Record 5 of Set 7 | quelimane
# Processing Record 6 of Set 7 | pajan
# Processing Record 7 of Set 7 | kemin
# Processing Record 8 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | kisangani
# Processing Record 10 of Set 7 | mporokoso
# Processing Record 11 of Set 7 | todos santos
# Processing Record 12 of Set 7 | konza
# Processing Record 13 of Set 7 | baherden
# Processing Record 14 of Set 7 | mananjary
# Processing Record 15 of Set 7 | boyuibe
# Processing Record 16 of Set 7 | urengoy
# Processing Record 17 of Set 7 | zhangjiakou
# Processing Record 18 of Set 7 | shenkursk
# Processing Record 19 of Set 7 | acarau
# Processing Record 20 of Set 7 | sao jose da coroa grande
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | tonantins
# Processing Record 23 of Set 7 | gayeri
# Processing Record 24 of Set 7 | sinnamary
# Processing Record 25 of Set 7 | natitingou
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | mugan
# Processing Record 29 of Set 7 | caorle
# Processing Record 30 of Set 7 | yulara
# Processing Record 31 of Set 7 | kennesaw
# Processing Record 32 of Set 7 | arlit
# Processing Record 33 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 7 | sao filipe
# Processing Record 35 of Set 7 | shiyan
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | alta floresta
# Processing Record 38 of Set 7 | makushino
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | port blair
# Processing Record 41 of Set 7 | viransehir
# Processing Record 42 of Set 7 | pangnirtung
# Processing Record 43 of Set 7 | shirokiy
# Processing Record 44 of Set 7 | tondano
# Processing Record 45 of Set 7 | datong
# Processing Record 46 of Set 7 | maple creek
# Processing Record 47 of Set 7 | erzin
# Processing Record 48 of Set 7 | burica
# City not found. Skipping...
# Processing Record 49 of Set 7 | dunedin
# Processing Record 50 of Set 7 | diamantino
# Processing Record 1 of Set 8 | khatanga
# Processing Record 2 of Set 8 | tateyama
# Processing Record 3 of Set 8 | pacific grove
# Processing Record 4 of Set 8 | rabak
# Processing Record 5 of Set 8 | carikar
# City not found. Skipping...
# Processing Record 6 of Set 8 | surt
# Processing Record 7 of Set 8 | teahupoo
# Processing Record 8 of Set 8 | luau
# Processing Record 9 of Set 8 | muros
# Processing Record 10 of Set 8 | tucumcari
# Processing Record 11 of Set 8 | vao
# Processing Record 12 of Set 8 | rutana
# Processing Record 13 of Set 8 | predivinsk
# Processing Record 14 of Set 8 | iskateley
# Processing Record 15 of Set 8 | pryamitsyno
# Processing Record 16 of Set 8 | am timan
# Processing Record 17 of Set 8 | khandagayty
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | kalaleh
# Processing Record 21 of Set 8 | paamiut
# Processing Record 22 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 8 | margate
# Processing Record 24 of Set 8 | teya
# Processing Record 25 of Set 8 | kommunisticheskiy
# Processing Record 26 of Set 8 | buluang
# Processing Record 27 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 28 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 8 | balikpapan
# Processing Record 30 of Set 8 | morros
# Processing Record 31 of Set 8 | akdepe
# Processing Record 32 of Set 8 | kavaratti
# Processing Record 33 of Set 8 | kahului
# Processing Record 34 of Set 8 | ojuelos de jalisco
# Processing Record 35 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 8 | tougue
# Processing Record 37 of Set 8 | rosamorada
# Processing Record 38 of Set 8 | chicama
# Processing Record 39 of Set 8 | haysyn
# Processing Record 40 of Set 8 | norman wells
# Processing Record 41 of Set 8 | najran
# Processing Record 42 of Set 8 | jasper
# Processing Record 43 of Set 8 | lavrentiya
# Processing Record 44 of Set 8 | lompoc
# Processing Record 45 of Set 8 | horni becva
# Processing Record 46 of Set 8 | malindi
# Processing Record 47 of Set 8 | lagos
# Processing Record 48 of Set 8 | camopi
# Processing Record 49 of Set 8 | chiredzi
# Processing Record 50 of Set 8 | ballina
# Processing Record 1 of Set 9 | anqing
# Processing Record 2 of Set 9 | port hardy
# Processing Record 3 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 9 | luganville
# Processing Record 5 of Set 9 | broken hill
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | aragats
# Processing Record 8 of Set 9 | dzerzhinskoye
# Processing Record 9 of Set 9 | katsuura
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | narrabri
# Processing Record 12 of Set 9 | amatitan
# Processing Record 13 of Set 9 | vuktyl
# Processing Record 14 of Set 9 | bantigue
# Processing Record 15 of Set 9 | amapa
# Processing Record 16 of Set 9 | mangalia
# Processing Record 17 of Set 9 | kaputa
# Processing Record 18 of Set 9 | popondetta
# Processing Record 19 of Set 9 | dera din panah
# City not found. Skipping...
# Processing Record 20 of Set 9 | ponta delgada
# Processing Record 21 of Set 9 | oktyabrskoye
# Processing Record 22 of Set 9 | lemesos
# City not found. Skipping...
# Processing Record 23 of Set 9 | biga
# Processing Record 24 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 9 | twentynine palms
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | eyrarbakki
# Processing Record 28 of Set 9 | tygda
# Processing Record 29 of Set 9 | caravelas
# Processing Record 30 of Set 9 | shache
# Processing Record 31 of Set 9 | sanmenxia
# Processing Record 32 of Set 9 | asfi
# Processing Record 33 of Set 9 | great yarmouth
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | boguchar
# Processing Record 36 of Set 9 | acapulco
# Processing Record 37 of Set 9 | langsa
# Processing Record 38 of Set 9 | fort nelson
# Processing Record 39 of Set 9 | vanavara
# Processing Record 40 of Set 9 | izhma
# Processing Record 41 of Set 9 | semey
# Processing Record 42 of Set 9 | qasigiannguit
# Processing Record 43 of Set 9 | lima
# Processing Record 44 of Set 9 | kushiro
# Processing Record 45 of Set 9 | jiaozuo
# Processing Record 46 of Set 9 | esperance
# Processing Record 47 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 9 | storforshei
# Processing Record 49 of Set 9 | farmington
# Processing Record 50 of Set 9 | santa fe
# Processing Record 1 of Set 10 | praya
# Processing Record 2 of Set 10 | kiunga
# Processing Record 3 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 10 | high level
# Processing Record 5 of Set 10 | ukiah
# Processing Record 6 of Set 10 | grammenitsa
# Processing Record 7 of Set 10 | hamilton
# Processing Record 8 of Set 10 | bataipora
# Processing Record 9 of Set 10 | nouadhibou
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | bati
# Processing Record 12 of Set 10 | olafsvik
# Processing Record 13 of Set 10 | san juan
# Processing Record 14 of Set 10 | bandarbeyla
# Processing Record 15 of Set 10 | haines junction
# Processing Record 16 of Set 10 | felipe carrillo puerto
# Processing Record 17 of Set 10 | westport
# Processing Record 18 of Set 10 | hambantota
# Processing Record 19 of Set 10 | carnot
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | gravelbourg
# Processing Record 22 of Set 10 | yashan
# Processing Record 23 of Set 10 | biryusinsk
# Processing Record 24 of Set 10 | micheweni
# Processing Record 25 of Set 10 | santa vitoria do palmar
# Processing Record 26 of Set 10 | basoko
# Processing Record 27 of Set 10 | central point
# Processing Record 28 of Set 10 | aripuana
# Processing Record 29 of Set 10 | port hedland
# Processing Record 30 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 10 | svetlyy
# Processing Record 32 of Set 10 | sabang
# Processing Record 33 of Set 10 | toktogul
# Processing Record 34 of Set 10 | garowe
# Processing Record 35 of Set 10 | hay river
# Processing Record 36 of Set 10 | korla
# Processing Record 37 of Set 10 | gazojak
# Processing Record 38 of Set 10 | jiwani
# Processing Record 39 of Set 10 | bethanien
# Processing Record 40 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 10 | birao
# Processing Record 42 of Set 10 | santa cruz
# Processing Record 43 of Set 10 | hendek
# Processing Record 44 of Set 10 | chapais
# Processing Record 45 of Set 10 | adrano
# Processing Record 46 of Set 10 | belle glade
# Processing Record 47 of Set 10 | ishigaki
# Processing Record 48 of Set 10 | sidi bu zayd
# City not found. Skipping...
# Processing Record 49 of Set 10 | killybegs
# Processing Record 50 of Set 10 | marawi
# Processing Record 1 of Set 11 | pangody
# Processing Record 2 of Set 11 | la romana
# Processing Record 3 of Set 11 | verkhnyaya inta
# Processing Record 4 of Set 11 | baturaja
# Processing Record 5 of Set 11 | vitim
# Processing Record 6 of Set 11 | aykhal
# Processing Record 7 of Set 11 | takoradi
# Processing Record 8 of Set 11 | kabanjahe
# Processing Record 9 of Set 11 | iralaya
# Processing Record 10 of Set 11 | tambura
# Processing Record 11 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 12 of Set 11 | huanan
# Processing Record 13 of Set 11 | sechura
# Processing Record 14 of Set 11 | eagle pass
# Processing Record 15 of Set 11 | whitehorse
# Processing Record 16 of Set 11 | hirado
# Processing Record 17 of Set 11 | aksarka
# Processing Record 18 of Set 11 | masterton
# Processing Record 19 of Set 11 | kathu
# Processing Record 20 of Set 11 | talcahuano
# Processing Record 21 of Set 11 | tecalitlan
# Processing Record 22 of Set 11 | skala fourkas
# Processing Record 23 of Set 11 | necochea
# Processing Record 24 of Set 11 | atambua
# Processing Record 25 of Set 11 | akyab
# Processing Record 26 of Set 11 | tilichiki
# Processing Record 27 of Set 11 | sawtell
# Processing Record 28 of Set 11 | asyut
# Processing Record 29 of Set 11 | puerto escondido
# Processing Record 30 of Set 11 | igarka
# Processing Record 31 of Set 11 | verkhnevilyuysk
# Processing Record 32 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 11 | kamaishi
# Processing Record 34 of Set 11 | santa comba
# Processing Record 35 of Set 11 | mizpe ramon
# City not found. Skipping...
# Processing Record 36 of Set 11 | baracoa
# Processing Record 37 of Set 11 | ibra
# Processing Record 38 of Set 11 | camana
# Processing Record 39 of Set 11 | kilindoni
# Processing Record 40 of Set 11 | bonavista
# Processing Record 41 of Set 11 | saint simons
# Processing Record 42 of Set 11 | zaragoza
# Processing Record 43 of Set 11 | coro
# Processing Record 44 of Set 11 | sisimiut
# Processing Record 45 of Set 11 | bodden town
# Processing Record 46 of Set 11 | mitu
# Processing Record 47 of Set 11 | odweyne
# Processing Record 48 of Set 11 | beroroha
# Processing Record 49 of Set 11 | verkhnyaya toyma
# Processing Record 50 of Set 11 | kangaatsiaq
# Processing Record 1 of Set 12 | san marino
# Processing Record 2 of Set 12 | puerto quijarro
# Processing Record 3 of Set 12 | malartic
# Processing Record 4 of Set 12 | oranjemund
# Processing Record 5 of Set 12 | namatanai
# Processing Record 6 of Set 12 | jacmel
# Processing Record 7 of Set 12 | malanje
# Processing Record 8 of Set 12 | touros
# Processing Record 9 of Set 12 | rocha
# Processing Record 10 of Set 12 | manokwari
# Processing Record 11 of Set 12 | aswan
# Processing Record 12 of Set 12 | la asuncion
# Processing Record 13 of Set 12 | chlorakas
# Processing Record 14 of Set 12 | oksfjord
# Processing Record 15 of Set 12 | shaunavon
# Processing Record 16 of Set 12 | yaritagua
# Processing Record 17 of Set 12 | avera
# Processing Record 18 of Set 12 | tiznit
# Processing Record 19 of Set 12 | nishihara
# Processing Record 20 of Set 12 | mount isa
# Processing Record 21 of Set 12 | flinders
# Processing Record 22 of Set 12 | dzilam gonzalez
# Processing Record 23 of Set 12 | launceston
# Processing Record 24 of Set 12 | villazon
# Processing Record 25 of Set 12 | san quintin
# Processing Record 26 of Set 12 | stokmarknes
# Processing Record 27 of Set 12 | saint anthony
# Processing Record 28 of Set 12 | ibipeba
# Processing Record 29 of Set 12 | cayenne
# Processing Record 30 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 12 | khandyga
# Processing Record 32 of Set 12 | kormilovka
# Processing Record 33 of Set 12 | kropotkin
# Processing Record 34 of Set 12 | buncrana
# Processing Record 35 of Set 12 | vilaka
# Processing Record 36 of Set 12 | fare
# Processing Record 37 of Set 12 | pilar
# Processing Record 38 of Set 12 | xihe
# Processing Record 39 of Set 12 | dongtai
# Processing Record 40 of Set 12 | mopipi
# Processing Record 41 of Set 12 | sola
# Processing Record 42 of Set 12 | pavlovskiy
# Processing Record 43 of Set 12 | jalu
# Processing Record 44 of Set 12 | dinghai
# Processing Record 45 of Set 12 | jinchang
# Processing Record 46 of Set 12 | kesztolc
# Processing Record 47 of Set 12 | pedasi
# Processing Record 48 of Set 12 | lugo
# Processing Record 49 of Set 12 | radlje ob dravi
# Processing Record 50 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 13 | auki
# Processing Record 2 of Set 13 | bukama
# Processing Record 3 of Set 13 | awbari
# Processing Record 4 of Set 13 | skibbereen
# Processing Record 5 of Set 13 | la massana
# Processing Record 6 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 13 | osterhofen
# Processing Record 8 of Set 13 | palkonda
# Processing Record 9 of Set 13 | sivas
# Processing Record 10 of Set 13 | manjacaze
# Processing Record 11 of Set 13 | chuguyevka
# Processing Record 12 of Set 13 | balaipungut
# Processing Record 13 of Set 13 | paraiso
# Processing Record 14 of Set 13 | salalah
# Processing Record 15 of Set 13 | davila
# Processing Record 16 of Set 13 | sloboda
# Processing Record 17 of Set 13 | paralimni
# Processing Record 18 of Set 13 | chhabra
# Processing Record 19 of Set 13 | nelson bay
# Processing Record 20 of Set 13 | tacuarembo
# Processing Record 21 of Set 13 | concord
# Processing Record 22 of Set 13 | kuusamo
# Processing Record 23 of Set 13 | yinchuan
# Processing Record 24 of Set 13 | singleton
# Processing Record 25 of Set 13 | dunda
# Processing Record 26 of Set 13 | lazaro cardenas
# Processing Record 27 of Set 13 | shuyskoye
# Processing Record 28 of Set 13 | soverato
# Processing Record 29 of Set 13 | zambezi
# Processing Record 30 of Set 13 | belmonte
# Processing Record 31 of Set 13 | orlovskiy
# Processing Record 32 of Set 13 | wanxian
# Processing Record 33 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 34 of Set 13 | asau
# Processing Record 35 of Set 13 | ayacucho
# Processing Record 36 of Set 13 | varhaug
# Processing Record 37 of Set 13 | kintampo
# Processing Record 38 of Set 13 | axim
# Processing Record 39 of Set 13 | qinhuangdao
# Processing Record 40 of Set 13 | eucaliptus
# Processing Record 41 of Set 13 | baykit
# Processing Record 42 of Set 13 | yabrud
# Processing Record 43 of Set 13 | wanaka
# Processing Record 44 of Set 13 | nuevo casas grandes
# Processing Record 45 of Set 13 | canico
# Processing Record 46 of Set 13 | forestville
# Processing Record 47 of Set 13 | yantal
# Processing Record 48 of Set 13 | ambon
# Processing Record 49 of Set 13 | susuman
# Processing Record 50 of Set 13 | fairbanks
# Processing Record 1 of Set 14 | asosa
# Processing Record 2 of Set 14 | noumea
# Processing Record 3 of Set 14 | henties bay
# Processing Record 4 of Set 14 | quesnel
# Processing Record 5 of Set 14 | puerto colombia
# Processing Record 6 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 14 | harrisburg
# Processing Record 8 of Set 14 | kensington
# Processing Record 9 of Set 14 | lebanon
# Processing Record 10 of Set 14 | dovers
# Processing Record 11 of Set 14 | ampanihy
# Processing Record 12 of Set 14 | belyy yar
# Processing Record 13 of Set 14 | mitsamiouli
# Processing Record 14 of Set 14 | aquiraz
# Processing Record 15 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 14 | goundam
# Processing Record 17 of Set 14 | rincon
# Processing Record 18 of Set 14 | maruoka
# Processing Record 19 of Set 14 | leiyang
# Processing Record 20 of Set 14 | pangkalanbuun
# Processing Record 21 of Set 14 | parbatipur
# Processing Record 22 of Set 14 | johnstown
# Processing Record 23 of Set 14 | el alto
# Processing Record 24 of Set 14 | yaounde
# Processing Record 25 of Set 14 | mayo
# Processing Record 26 of Set 14 | digby
# Processing Record 27 of Set 14 | cibitoke
# Processing Record 28 of Set 14 | behshahr
# Processing Record 29 of Set 14 | riyadh
# Processing Record 30 of Set 14 | nara
# Processing Record 31 of Set 14 | morant bay
# Processing Record 32 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 14 | mwinilunga
# Processing Record 34 of Set 14 | rio grande
# Processing Record 35 of Set 14 | hokitika
# Processing Record 36 of Set 14 | abnub
# Processing Record 37 of Set 14 | farah
# Processing Record 38 of Set 14 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 39 of Set 14 | taltal
# Processing Record 40 of Set 14 | alice springs
# Processing Record 41 of Set 14 | joshimath
# Processing Record 42 of Set 14 | hervey bay
# Processing Record 43 of Set 14 | daru
# Processing Record 44 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 14 | devils lake
# Processing Record 46 of Set 14 | trinidad
# Processing Record 47 of Set 14 | pisco
# Processing Record 48 of Set 14 | gotsu
# Processing Record 49 of Set 14 | matara
# Processing Record 50 of Set 14 | swanton
# Processing Record 1 of Set 15 | mokhsogollokh
# Processing Record 2 of Set 15 | komsomolskiy
# Processing Record 3 of Set 15 | sadiqabad
# Processing Record 4 of Set 15 | gisborne
# Processing Record 5 of Set 15 | abha
# Processing Record 6 of Set 15 | lujan
# Processing Record 7 of Set 15 | novikovo
# Processing Record 8 of Set 15 | stornoway
# Processing Record 9 of Set 15 | taoudenni
# Processing Record 10 of Set 15 | tiksi
# Processing Record 11 of Set 15 | novichikha
# Processing Record 12 of Set 15 | adrar
# Processing Record 13 of Set 15 | ouallam
# Processing Record 14 of Set 15 | koslan
# Processing Record 15 of Set 15 | marrakesh
# Processing Record 16 of Set 15 | udachnyy
# Processing Record 17 of Set 15 | simao dias
# Processing Record 18 of Set 15 | eureka
# Processing Record 19 of Set 15 | vila franca do campo
# Processing Record 20 of Set 15 | encruzilhada
# Processing Record 21 of Set 15 | nakonde
# Processing Record 22 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 23 of Set 15 | vilhena
# Processing Record 24 of Set 15 | thonon-les-bains
# Processing Record 25 of Set 15 | januaria
# Processing Record 26 of Set 15 | chany
# Processing Record 27 of Set 15 | moose factory
# Processing Record 28 of Set 15 | vanimo
# Processing Record 29 of Set 15 | balkhash
# Processing Record 30 of Set 15 | pionerskiy
# Processing Record 31 of Set 15 | conceicao do araguaia
# Processing Record 32 of Set 15 | baheri
# Processing Record 33 of Set 15 | lorengau
# Processing Record 34 of Set 15 | maningrida
# Processing Record 35 of Set 15 | tlacolula
# Processing Record 36 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 15 | staraya sunzha
# Processing Record 38 of Set 15 | rab
# City not found. Skipping...
# Processing Record 39 of Set 15 | ostersund
# Processing Record 40 of Set 15 | marsh harbour
# Processing Record 41 of Set 15 | ruwi
# Processing Record 42 of Set 15 | andilamena
# Processing Record 43 of Set 15 | praia
# Processing Record 44 of Set 15 | lundazi
# Processing Record 45 of Set 15 | pedernales
# Processing Record 46 of Set 15 | anori
# Processing Record 47 of Set 15 | springbok
# Processing Record 48 of Set 15 | portsmouth
# Processing Record 49 of Set 15 | ust-maya
# Processing Record 50 of Set 15 | alekseyevsk
# Processing Record 1 of Set 16 | pazardzik
# City not found. Skipping...
# Processing Record 2 of Set 16 | yaqui
# Processing Record 3 of Set 16 | edson
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries to a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     46.51        66          40
# 1      Victoria      HK  22.2855  114.1577     86.18        84         100
# 2        Dikson      RU  73.5069   80.5464     39.90        96         100
# 3   Port Alfred      ZA -33.5906   26.8910     54.18        90          37
# 4  San Patricio      US  28.0170  -97.5169     91.29        64           6
#
#    Wind Speed Current Description
# 0        6.91    scattered clouds
# 1        3.00     overcast clouds
# 2       19.22     overcast clouds
# 3        5.01    scattered clouds
# 4       14.25           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
